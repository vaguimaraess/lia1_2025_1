# %% [markdown]
# <hr style="height:10px">
#
# <div class='container2'>
# 		<div>
# 			<img src='images\header.png' ALIGN='left' style='width:10em'>
# 		</div>
# 	<div style='padding: 0 7em 2em 12em;'>
# 	<h1>Laboratório de Inovação e Automação 1 (LIA 1)</h1>
# 	<div style="font-size:12pt;float:left;"> 2025/1 | 46M34 | Sala 200 CAE</div><br><br>
#     <div style="font-size:12pt;float:left;"><b>Projetos de Inteligência Artificial - Análise Exploratória de Dados </b></div>
# 	</div>
# </div>
#
#
#  <hr style="height:5px">
#
#
# <h2>Aula 6 - Introdução à Ciência de Dados - <a href="https://www.kaggle.com/datasets/arshid/iris-flower-dataset">Iris Dataset </a> </h2>
#
# Notebook desenvolvido por: <a href="http://lattes.cnpq.br/1346824250595330">Prof. Dr. Adriano C. Santana</a>
#
#  <hr style="height:2px">

# %%
# Confirmar a versão da Linguagem Python instalada
from platform import python_version
print(f'A versão da linguagem Python usada neste projeto é a {python_version()}!')
# Out:
# A versão da linguagem Python usada neste projeto é a 3.12.7!

# %%
# Verificar se o Python está funcionando
print('Bye bye, World!')
# Out:
# Bye bye, World!

# %% [markdown]
# ---
# ## 1. Bibliotecas Necessárias para o Notebook (Aula)
#
# Para este notebook, deve ser utilizada a mesma versão apresentada pelo professor da disciplina.
#
# * [`matplotlib`](https://matplotlib.org/) (versão 3.1.3 ou superior): construção e exibição de gráficos variados.
# * [`seaborn`](https://seaborn.pydata.org/) (versão 0.10.0 ou superior): construção e exibição de gráficos variados.
# * [`numpy`](https://numpy.org) (versão 1.16.2 ou superior): manipulação de dados em formato de vetores e matrizes.
# * [`pandas`](https://pandas.pydata.org/pandas-docs/stable/index.html) (versão 0.24.1 ou superior): manipulação de dados em formato de tabelas.
#
# Será utilizado o conjunto de dados que se encontra no diretório `datasets`, em formato de arquivo `.csv e/ou .txt`.

# %% [markdown]
# ---
# ## 2. Carregar e Exibir os Dados da Fonte
#
# Primeiro, vamos importar todas as bibliotecas que serão utilizadas no projeto.

# %%
# -*- coding: utf-8 -*-

# importar a biblioteca usada para trabalhar com vetores e matrizes
import numpy as np

# importar a biblioteca usada para trabalhar com dataframes (dados em formato de tabela) e análise de dados
import pandas as pd 

# importar as bibliotecas usadas para geração de gráficos
import seaborn as sns
import matplotlib.pyplot as plt

print('Bibliotecas carregadas com sucesso!')
# Out:
# Bibliotecas carregadas com sucesso!

# %% [markdown]
# ### Apresentação da base de dados
#
# A base de dados de Transformadores de Media/Baixa Tensão será usada para apresentação dos conceitos a serem estudados.
# <br>
# <br>
# <center>
# <div style="display:inline-block;">
#     <div>
#     <div style="padding: 5px; float: left;">
#         <img src="images/linha.jpg" style="height:180px;"/>
#         <center>Linha de Transmissão</center>
#     </div>
#     <div style="padding: 5px; float: left;">
#         <img src="images/transformador.jpg"  style="height:180px;"/>
#         <center>Transformadores</center>
#     </div>
#     <div style="padding: 5px; float: left;">
#         <img src="images/imagem1.jpg"  style="height:180px;"/>
#         <center>Unidade Consumidoras</center>
#     </div>
#     </div>
# </div>
# </center>

# %% [markdown]
# Primeiro: vamos importar os dados para o dataframe.

# %%
# importar o arquivo e guardar em um dataframe do Pandas
df_dataset = pd.read_excel('datasets/tabela2.xlsx', index_col=None)

print('Dados importados com sucesso!')
# Out:
# Dados importados com sucesso!

# %% [markdown]
# Segundo: vamos dar uma olhada rápida na base de dados.

# %%
# exibir uma amostra do dataframe
#display(df_dataset.head())
display(df_dataset)
# Out:
#         OBJECTID                  Subestação          Trafo  QtdEquipamento  \
# 0              1                       EDEIA  Transformador               1
# 1              2  SENADOR CANEDO TRANSMISSAO  Transformador               1
# 2              3                     CATALAO  Transformador               1
# 3              4                      URUACU  Transformador               1
# 4              5                        GOYA  Transformador               1
# ...          ...                         ...            ...             ...
# 251228    251229              CACHOEIRA ALTA  Transformador               1
# 251229    251230                   ATLANTICO  Transformador               1
# 251230    251231                   PORANGATU  Transformador               1
# 251231    251232        PACAEMBU (NOVO GAMA)  Transformador               1
# 251232    251233    ITAPURANGA (TRANSMISSAO)  Transformador               1
#
#        Potência Nominal Tensão 1º Tensão 2º      Tensão 3º  \
# 0                45 kVA    13,8kV      380V  Não informado
# 1                75 kVA    13,8kV      380V  Não informado
# 2                75 kVA    13,8kV      380V  Não informado
# 3                75 kVA    34,5kV      380V  Não informado
# 4               750 kVA    13,8kV      380V  Não informado
# ...                 ...       ...       ...            ...
# 251228           45 kVA    13,8kV      380V  Não informado
# 251229          500 kVA    13,8kV      380V  Não informado
# 251230           75 kVA    13,8kV      380V  Não informado
# 251231          150 kVA    13,8kV      380V  Não informado
# 251232           75 kVA    13,8kV      380V  Não informado
#
#                          Ligação   Latitude  Longitude
# 0       Delta / Estrela Aterrado -17.427718 -49.670590
# 1       Delta / Estrela Aterrado -16.699347 -49.109833
# 2       Delta / Estrela Aterrado -18.168049 -47.946534
# 3       Delta / Estrela Aterrado -14.521319 -49.053754
# 4       Delta / Estrela Aterrado -16.653497 -49.328906
# ...                          ...        ...        ...
# 251228  Delta / Estrela Aterrado -18.758199 -51.352089
# 251229  Delta / Estrela Aterrado -16.735369 -49.293924
# 251230  Delta / Estrela Aterrado -13.450775 -49.152910
# 251231  Delta / Estrela Aterrado -16.056892 -47.985748
# 251232  Delta / Estrela Aterrado -15.760713 -49.851801
#
# [251233 rows x 11 columns]

# %% [markdown]
# ---
# ## 3. Pré-processamento
#
# Minimizar ou eliminar problemas existentes em um conjunto de dados, bem como torná-los mais adequados para sua utilização por um determinado algoritmo de aprendizagem de máquina.
#
# ## 3.1 Eliminação de atributos irrelevantes
#
# O objetivo do projeto é identificar o transformador, que é a (`classe`). Não é preciso uma análise profunda para observar que os atributos `OBJECTID` e `QtdEquipamento` não contribuem para a identificação. Portanto, em uma tarefa de aprendizado de máquina, devemos remover esses atributos, pois são irrelevantes.
#
# *Em cenários reais, muitas vezes é necessário consultar especialistas para ajudar a identificar quais atributos são irrelevantes.*

# %%
# remover as colunas id_planta e cidade_origem
df_dataset = df_dataset.drop(columns=['OBJECTID','QtdEquipamento'])

# imprimir o dataframe
display(df_dataset.head(n=10))
# Out:
#                    Subestação          Trafo Potência Nominal Tensão 1º  \
# 0                       EDEIA  Transformador           45 kVA    13,8kV
# 1  SENADOR CANEDO TRANSMISSAO  Transformador           75 kVA    13,8kV
# 2                     CATALAO  Transformador           75 kVA    13,8kV
# 3                      URUACU  Transformador           75 kVA    34,5kV
# 4                        GOYA  Transformador          750 kVA    13,8kV
# 5                CALDAS NOVAS  Transformador          300 kVA    13,8kV
# 6                   ATLANTICO  Transformador           75 kVA    13,8kV
# 7                 FERROVIARIO  Transformador          300 kVA    13,8kV
# 8                        REAL  Transformador           75 kVA    13,8kV
# 9          ITIQUIRA (FORMOSA)  Transformador           75 kVA    13,8kV
#
#   Tensão 2º      Tensão 3º                   Ligação   Latitude  Longitude
# 0      380V  Não informado  Delta / Estrela Aterrado -17.427718 -49.670590
# 1      380V  Não informado  Delta / Estrela Aterrado -16.699347 -49.109833
# 2      380V  Não informado  Delta / Estrela Aterrado -18.168049 -47.946534
# 3      380V  Não informado  Delta / Estrela Aterrado -14.521319 -49.053754
# 4      380V  Não informado  Delta / Estrela Aterrado -16.653497 -49.328906
# 5      380V  Não informado  Delta / Estrela Aterrado -17.741823 -48.628370
# 6      380V  Não informado  Delta / Estrela Aterrado -16.748379 -49.333127
# 7      380V  Não informado  Delta / Estrela Aterrado -16.657606 -49.245946
# 8      380V  Não informado  Delta / Estrela Aterrado -16.753198 -49.226365
# 9      380V  Não informado  Delta / Estrela Aterrado -15.526843 -47.332703

# %% [markdown]
# ---
# ## 3.2 Tratamento de atributos com valores ausentes
#
# Verificar se existem atributos com valores ausentes (NaN) na base de dados.

# %%
# índices das linhas que contém valores NaN
idxRowNan = pd.isnull(df_dataset).any(axis=1).to_numpy().nonzero()

# imprime apenas as linhas com valores ausentes
display(df_dataset.iloc[idxRowNan])
# Out:
#        Subestação          Trafo Potência Nominal Tensão 1º Tensão 2º  \
# 324           NaN  Transformador         37,5 kVA    7,96kV      440V
# 439           NaN  Transformador           75 kVA    13,8kV      380V
# 528           NaN  Transformador           75 kVA    13,8kV      380V
# 1674          NaN  Transformador           25 kVA    7,96kV      440V
# 2014          NaN  Transformador          2,5 MVA    34,5kV    13,8kV
# ...           ...            ...              ...       ...       ...
# 249057        NaN  Transformador           15 kVA    7,96kV      440V
# 249914        NaN  Transformador           15 kVA    7,96kV      440V
# 250028        NaN  Transformador           75 kVA    13,8kV      380V
# 250816        NaN  Transformador           10 kVA  19,919kV      440V
# 251095        NaN  Transformador           10 kVA    7,96kV      440V
#
#             Tensão 3º                         Ligação   Latitude  Longitude
# 324     Não informado  H Simples / x Simpes Derivação        NaN        NaN
# 439     Não informado        Delta / Estrela Aterrado        NaN        NaN
# 528     Não informado        Delta / Estrela Aterrado        NaN        NaN
# 1674    Não informado  H Simples / x Simpes Derivação        NaN        NaN
# 2014    Não informado        Delta / Estrela Aterrado -16.686011 -49.234117
# ...               ...                             ...        ...        ...
# 249057  Não informado  H Simples / x Simpes Derivação        NaN        NaN
# 249914  Não informado  H Simples / x Simpes Derivação        NaN        NaN
# 250028  Não informado        Delta / Estrela Aterrado        NaN        NaN
# 250816  Não informado  H Simples / x Simpes Derivação        NaN        NaN
# 251095  Não informado  H Simples / x Simpes Derivação        NaN        NaN
#
# [303 rows x 9 columns]

# %% [markdown]
# Preencher os valores - NaN - com a dos valores conhecidos de `Longitude` e `Latitude`, na respectiva classe. Como também, preencher os valores - NaN -  da Subestação por `Armazenamento Técnico`. Neste caso, a classe é a mesma: `Transformador`.

# %%
import pandas as pd

def trataFaltantes(df_dataset):
    # Remove as linhas onde 'Subestação' é nulo
    df_dataset.loc[df_dataset['Subestação'].isnull(), 'Subestação'] = "Armazenamento técnico"

    # Substitui NaN em Latitude e Longitude pelos valores fornecidos
    df_dataset.loc[df_dataset['Latitude'].isnull(), 'Latitude'] = -16.686011
    df_dataset.loc[df_dataset['Longitude'].isnull(), 'Longitude'] = -49.234117


    return df_dataset

# Aplica a função ao dataset
df_dataset = trataFaltantes(df_dataset)

# Exibe apenas as linhas que antes possuíam valores NaN
print('\nObjeto(s) com valor(es) nulo(s):')
display(df_dataset.iloc[idxRowNan])
# Out:
# Objeto(s) com valor(es) nulo(s):
#                    Subestação          Trafo Potência Nominal Tensão 1º  \
# 324     Armazenamento técnico  Transformador         37,5 kVA    7,96kV
# 439     Armazenamento técnico  Transformador           75 kVA    13,8kV
# 528     Armazenamento técnico  Transformador           75 kVA    13,8kV
# 1674    Armazenamento técnico  Transformador           25 kVA    7,96kV
# 2014    Armazenamento técnico  Transformador          2,5 MVA    34,5kV
# ...                       ...            ...              ...       ...
# 249057  Armazenamento técnico  Transformador           15 kVA    7,96kV
# 249914  Armazenamento técnico  Transformador           15 kVA    7,96kV
# 250028  Armazenamento técnico  Transformador           75 kVA    13,8kV
# 250816  Armazenamento técnico  Transformador           10 kVA  19,919kV
# 251095  Armazenamento técnico  Transformador           10 kVA    7,96kV
#
#        Tensão 2º      Tensão 3º                         Ligação   Latitude  \
# 324         440V  Não informado  H Simples / x Simpes Derivação -16.686011
# 439         380V  Não informado        Delta / Estrela Aterrado -16.686011
# 528         380V  Não informado        Delta / Estrela Aterrado -16.686011
# 1674        440V  Não informado  H Simples / x Simpes Derivação -16.686011
# 2014      13,8kV  Não informado        Delta / Estrela Aterrado -16.686011
# ...          ...            ...                             ...        ...
# 249057      440V  Não informado  H Simples / x Simpes Derivação -16.686011
# 249914      440V  Não informado  H Simples / x Simpes Derivação -16.686011
# 250028      380V  Não informado        Delta / Estrela Aterrado -16.686011
# 250816      440V  Não informado  H Simples / x Simpes Derivação -16.686011
# 251095      440V  Não informado  H Simples / x Simpes Derivação -16.686011
#
#         Longitude
# 324    -49.234117
# 439    -49.234117
# 528    -49.234117
# 1674   -49.234117
# 2014   -49.234117
# ...           ...
# 249057 -49.234117
# 249914 -49.234117
# 250028 -49.234117
# 250816 -49.234117
# 251095 -49.234117
#
# [303 rows x 9 columns]

# %% [markdown]
# ---
# ## 3.3 Tratamento de dados inconsistentes ou redundantes
#
# Verificar se existem dados inconsistentes ou redundantes. A forma mais comum de inconsistência é quando há registros representados por atributos com todos os valores iguais, mas com diagnóstico diferentes. A redundância é dada pela repetição de linhas na base de dados.

# %%
df_duplicates = df_dataset[ df_dataset.duplicated(subset=['Subestação','Trafo','Potência Nominal','Tensão 1º','Tensão 2º','Tensão 3º','Ligação','Latitude','Longitude' ],keep=False)] 

# se houver valores redundantes ou inconsistentes, imprima 
if len(df_duplicates) > 0:
    print('\nObjeto(s) redundante(s) e/ou inconsistente(s):')
    display(df_duplicates)
else:
    print('Não existem objetos redundantes e/ou inconsistentes!')
# Out:
# Objeto(s) redundante(s) e/ou inconsistente(s):
#                    Subestação          Trafo Potência Nominal Tensão 1º  \
# 324     Armazenamento técnico  Transformador         37,5 kVA    7,96kV
# 439     Armazenamento técnico  Transformador           75 kVA    13,8kV
# 528     Armazenamento técnico  Transformador           75 kVA    13,8kV
# 1076        ALVORADA DO NORTE  Transformador           30 kVA    34,5kV
# 1674    Armazenamento técnico  Transformador           25 kVA    7,96kV
# ...                       ...            ...              ...       ...
# 249057  Armazenamento técnico  Transformador           15 kVA    7,96kV
# 249914  Armazenamento técnico  Transformador           15 kVA    7,96kV
# 250028  Armazenamento técnico  Transformador           75 kVA    13,8kV
# 250816  Armazenamento técnico  Transformador           10 kVA  19,919kV
# 251095  Armazenamento técnico  Transformador           10 kVA    7,96kV
#
#        Tensão 2º      Tensão 3º                         Ligação   Latitude  \
# 324         440V  Não informado  H Simples / x Simpes Derivação -16.686011
# 439         380V  Não informado        Delta / Estrela Aterrado -16.686011
# 528         380V  Não informado        Delta / Estrela Aterrado -16.686011
# 1076        380V  Não informado        Delta / Estrela Aterrado -14.487785
# 1674        440V  Não informado  H Simples / x Simpes Derivação -16.686011
# ...          ...            ...                             ...        ...
# 249057      440V  Não informado  H Simples / x Simpes Derivação -16.686011
# 249914      440V  Não informado  H Simples / x Simpes Derivação -16.686011
# 250028      380V  Não informado        Delta / Estrela Aterrado -16.686011
# 250816      440V  Não informado  H Simples / x Simpes Derivação -16.686011
# 251095      440V  Não informado  H Simples / x Simpes Derivação -16.686011
#
#         Longitude
# 324    -49.234117
# 439    -49.234117
# 528    -49.234117
# 1076   -46.603384
# 1674   -49.234117
# ...           ...
# 249057 -49.234117
# 249914 -49.234117
# 250028 -49.234117
# 250816 -49.234117
# 251095 -49.234117
#
# [781 rows x 9 columns]

# %% [markdown]
# Existem objetos redundantes (duplicados) e outros inconsistentes (iguais, exceto diagnóstico distintos).
#
# Primeiro, serão removidos os registros redundantes, mantendo na base apenas o primeiro deles.

# %%
def delDuplicatas( df_dataset ):
    
    # remove o(s) objeto(s) duplicado(s), mantendo apenas a primeira ocorrência
    df_dataset = df_dataset.drop_duplicates(keep = 'first')

    return df_dataset

df_dataset = delDuplicatas( df_dataset )

# %% [markdown]
# Após remover os objetos redundantes, é preciso checar se há registros inconsistentes.

# %%
df_duplicates = df_dataset[ df_dataset.duplicated(subset=['Subestação','Trafo','Potência Nominal','Tensão 1º','Tensão 2º','Tensão 3º','Ligação','Latitude','Longitude' ],keep=False)] 

# se existir objetos inconsistentes, exibir
if len(df_duplicates)>0:
    print('\nObjeto(s) inconsistente(s):')
    display(df_duplicates)
else:
    print('Não existem objetos redundantes e/ou inconsistentes!')
# Out:
# Não existem objetos redundantes e/ou inconsistentes!

# %% [markdown]
# Existem registros inconsistentes. Nesse caso, como não é possível saber qual deles está correto. Assim, eles devem ser eliminados.

# %%
def delInconsistencias( df_dataset ):

    df_dataset = df_dataset.drop_duplicates(subset=['Subestação','Trafo','Potência Nominal','Tensão 1º','Tensão 2º','Tensão 3º','Ligação','Latitude','Longitude' ], keep = False)    
  
    return df_dataset

df_dataset = delInconsistencias( df_dataset )

# obtém apenas as amostras onde os valores dos atributos estão duplicados
df_duplicates = df_dataset[ df_dataset.duplicated(subset=['Subestação','Trafo','Potência Nominal','Tensão 1º','Tensão 2º','Tensão 3º','Ligação','Latitude','Longitude' ],keep=False)] 

# se existir registros redundantes ou inconsistentes, exibir
if len(df_duplicates) > 0:
    display(df_duplicates)
else:
    print('Não existem registros redundantes e/ou inconsistentes!')
# Out:
# Não existem registros redundantes e/ou inconsistentes!

# %%
display(df_dataset.tail())
# Out:
#                       Subestação          Trafo Potência Nominal Tensão 1º  \
# 251228            CACHOEIRA ALTA  Transformador           45 kVA    13,8kV
# 251229                 ATLANTICO  Transformador          500 kVA    13,8kV
# 251230                 PORANGATU  Transformador           75 kVA    13,8kV
# 251231      PACAEMBU (NOVO GAMA)  Transformador          150 kVA    13,8kV
# 251232  ITAPURANGA (TRANSMISSAO)  Transformador           75 kVA    13,8kV
#
#        Tensão 2º      Tensão 3º                   Ligação   Latitude  \
# 251228      380V  Não informado  Delta / Estrela Aterrado -18.758199
# 251229      380V  Não informado  Delta / Estrela Aterrado -16.735369
# 251230      380V  Não informado  Delta / Estrela Aterrado -13.450775
# 251231      380V  Não informado  Delta / Estrela Aterrado -16.056892
# 251232      380V  Não informado  Delta / Estrela Aterrado -15.760713
#
#         Longitude
# 251228 -51.352089
# 251229 -49.293924
# 251230 -49.152910
# 251231 -47.985748
# 251232 -49.851801

# %% [markdown]
# ---
# ## 4. Análise dos Dados
# A análise das características presentes em um conjunto de dados permite a descoberta de padrões e tendências que podem fornecer informações valiosas para compreender o processo que gerou os dados.

# %%
# apresenta as principais estatísticas da base de dados para atributos numéricos
df_detalhes = df_dataset.describe()

display(df_detalhes)
# Out:
#             Latitude      Longitude
# count  250712.000000  250712.000000
# mean      -16.206835     -49.327518
# std         1.365157       1.329923
# min       -19.436058     -53.211493
# 25%       -17.080439     -50.100157
# 50%       -16.381764     -49.264283
# 75%       -15.389431     -48.492052
# max       -12.514942     -45.973074

# %% [markdown]
# ---
# ## 4.1 Detecção de outliers (valor atípico)
# Outro passo importante na análise e tratamento dos dados é a detecção de outliers (dados gerados por leituras incorretas, erros de digitação etc).

# %% [markdown]
# `Gráfico Box Plot`
#
# Uma das maneiras mais simples de verificar se os dados contém outliers.

# %%
# gerar um bloxplot para cada atributo
df_dataset.boxplot(figsize=(15,7))
plt.show()

# %% [markdown]
# O box plot está indicando que os atributos `Latitude` e `Longitude` possuem *outliers*, o que pode prejudicar o desempenho de vários métodos de aprendizado de máquina, pois tratam-se de objetos com valores de atributos incorretos.

# %%
import numpy as np
import pandas as pd

def removeOutliers(df_dataset):
    """
    Remove os outliers da base de dados
    """
    numeric_columns = df_dataset.select_dtypes(include=[np.number]).columns  # Seleciona colunas numéricas

    for atributo in numeric_columns:
        q75, q25 = np.percentile(df_dataset[atributo].dropna(), [75, 25])  # Remove NaNs antes do cálculo
        IQR = q75 - q25
        limite_inferior = q25 - 1.5 * IQR
        limite_superior = q75 + 1.5 * IQR

        # Remove outliers
        df_dataset = df_dataset[(df_dataset[atributo] >= limite_inferior) & (df_dataset[atributo] <= limite_superior)]

    return df_dataset
    
# remove os outliers
df_dataset = removeOutliers( df_dataset )

# apresenta as principais estatísticas sobre a base de dados
df_dataset.boxplot(figsize=(15,7))
plt.show()

# %% [markdown]
# Depois da remoção, o box plot e os gráficos de dispersão indicam que não há mais nenhum *outlier* na base de dados.
